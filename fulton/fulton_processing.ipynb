# %% [markdown]
# # Fulton Parcel Processing

# %%
import pandas as pd
import os

pd.set_option('display.max_columns', None)

# %%
# Original names of variables, include these on data format sheet
original_vars = [
    'Taxyr', 'Parid', 'Situs Adrno', 'Situs Adrdir',
    'Situs Adrstr', 'Situs Adrsuf', 'Situs Adrsuf2',
    'Cityname', 'Class', 'Luc', 'Livunit',
    'Taxdist', 'Own1', 'Own2', 'Owner Adrno',
    'Owner Adradd', 'Owner Adrdir', 'Owner Adrstr',
    'Owner Adrsuf', 'Owner Adrsuf2', 'Cityname.1',
    'Statecode', 'Country', 'Unitno', 'Zip1', 'Reascd',
    'Aprland', 'Aprbldg', 'Revcode', 'Revreas', 'Aprtot',
    'D Yrblt', 'D Effyr', 'D Yrremod', 'D Grade', 'Sfla'
]
# New names of variables, 'final variable name' on data format sheet
new_var_map = {
    'Taxyr': 'tax_year', 'Parid': 'parcel_id', 'site_addr': 'site_addr',
    'Class': 'site_class_parcel', 'Luc': 'site_luc_parcel',
    'Taxdist': 'tax_district', 'Own1': 'owner_name_1', 
    'Own2': 'owner_name_2', 'Zip1': 'owner_zip', 'owner_addr': 'owner_addr',
    'Reascd': 'reas_cd', 'Revcode': 'rev_code',
    'Revreas': 'rev_reas', 'Aprtot': 'appr_total',
    'Aprland': 'appr_land', 'Aprbldg': 'appr_build', 'D Yrblt': 'year_built',
    'D Effyr': 'year_eff', 'D Yrremod': 'year_remodel', 'D Grade': 'grade',
    'Livunit': 'num_units', 'Sfla': 'building_area'
}
# New variable names ('final variable name' on data format sheet)
# with their associated datatype mapping
dtypes = {
    'tax_year': 'int16', 'parcel_id': 'string', 'site_addr': 'string',
    'site_class_parcel': 'category', 'site_luc_parcel': 'category',
    'tax_district': 'category', 'owner_name_1': 'string',
    'owner_name_2': 'string', 'owner_zip': 'string', 'owner_addr': 'string',
    'reas_cd': 'string', 'rev_code': 'string', 'rev_reas': 'string',
    'appr_total': 'float32', 'appr_land': 'float32', 'appr_build': 'float32',
    'year_built': 'int16', 'year_eff': 'int16',
    'year_remodel': 'int16', 'grade': 'category',
    'num_units': 'int16', 'building_area': 'float32'
}

# %% [markdown]
# ## Read in Files

# %% [markdown]
# Get all file names in directory.

# %%
prefix_path = '../data/fulton/parcels/'
file_paths = os.listdir(prefix_path)
file_paths[:2] # printing out the first 2 files
# Out:
# ['14_2010-2011.xlsx', '14_2012-2013.xlsx']

# %% [markdown]
# Loop through files and read them in. Store them in a list of dataframes. appendeded on a single file first.

# %%
dfs = []

for file in file_paths[4:6]:
    dfs.append(
        pd.read_excel(prefix_path + file)
    )

# %% [markdown]
# ## Append Files

# %% [markdown]
# Dropping extra vars.
#
# Recommend dropping uneeded variables first if data size is large; the best way to do this is by only keeping variables we need because we don't need many.
#
# We also want to remove the last row of each file (for Fulton, at least), because it simply contains a 'Count Distinct' value in the source data- this is not something we want.

# %%
# Calculating total num of rows to verify next step
total_rows = 0

for index, df in enumerate(dfs):
    init = len(df.columns)
    dfs[index] = df[original_vars][:-1]
    total_rows += len(df)
    print(f'Dropped {init - len(df.columns)} columns')
# Out:
# Dropped 0 columns
# Dropped 0 columns

# %% [markdown]
# Now all dfs should have the same columns. We can append.

# %%
appended = pd.concat(dfs, ignore_index=True)

init_size = len(appended) # Take inital size of data for later calc

print(f'Appended has {len(appended)} rows; total rows calculated '
      + f'previously is {total_rows}')
# Out:
# Appended has 175077 rows; total rows calculated previously is 175079

# %% [markdown]
# Construct the derived variables (e.g. site_addr from the multiple site address variables in this data). However, before we can do this, we need to clean each of the columns we will join to create this variable.
#
# More specifically, we need check how many None values there are in each column, then replace them with something that makes sense. This is because if you try to add a row with value None for one column (say address num) and "Main Street" for another, the result will be None.

# %%
check_vars = ['Situs Adrno', 'Situs Adrdir','Situs Adrstr',
              'Situs Adrsuf', 'Situs Adrsuf2', 'Cityname',
              'Owner Adrno', 'Owner Adrstr', 'Owner Adradd',
              'Owner Adrdir', 'Owner Adrsuf', 'Owner Adrsuf2',
              'Cityname.1', 'Statecode', 'Unitno']

print("Percent NA by Variable ---")
for v in check_vars:
    pct_na = len(appended[appended[v].isna()]) / len(appended)* 100
    print(f'{v}: {pct_na:.2f}')
# Out:
# Percent NA by Variable ---
# Situs Adrno: 0.01
# Situs Adrdir: 99.91
# Situs Adrstr: 0.00
# Situs Adrsuf: 1.39
# Situs Adrsuf2: 25.59
# Cityname: 0.08
# Owner Adrno: 5.33
# Owner Adrstr: 0.39
# Owner Adradd: 99.53
# Owner Adrdir: 96.72
# Owner Adrsuf: 7.90
# Owner Adrsuf2: 51.49
# Cityname.1: 0.36
# Statecode: 0.38
# Unitno: 80.21

# %% [markdown]
# Let's investigate some examples of NA for Cityname because, while insignificant, it is an important column.

# %%
appended[appended['Cityname'].isna()].sample(2)
# Out:
#         Taxyr            Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 9737   2017.0  14 002000072170        791.0          NaN        WYLIE
# 34060  2017.0  14 008400072538        425.0          NaN       CHAPEL
#
#       Situs Adrsuf Situs Adrsuf2 Cityname Class  Luc  Livunit Taxdist  \
# 9737            ST            SE      NaN    R3  106      1.0     05T
# 34060           ST            SW      NaN    R3  106      1.0     05Z
#
#                        Own1 Own2  Owner Adrno Owner Adradd Owner Adrdir  \
# 9737       SEMANICK KEVIN J  NaN        791.0          NaN          NaN
# 34060  CRUMP MARK & SHIRLEY  NaN        425.0          NaN          NaN
#
#       Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1 Statecode Country  \
# 9737         WYLIE           ST           NaN    ATLANTA        GA     NaN
# 34060       CHAPEL           ST           NaN    ATLANTA        GA     NaN
#
#       Unitno   Zip1 Reascd  Aprland   Aprbldg  Revcode Revreas    Aprtot  \
# 9737    1006  30316    NaN  22000.0  193700.0      NaN     NaN  215700.0
# 34060   3208  30313    NaN  15100.0   66500.0      NaN     NaN   81600.0
#
#        D Yrblt  D Effyr  D Yrremod D Grade    Sfla
# 9737    2006.0      NaN        NaN       A  1736.0
# 34060   2006.0      NaN        NaN      B+  1196.0

# %%
appended[appended['Situs Adrstr'].isna()].sample(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\nicho\Documents\research\ga-tax-assessment\fulton\fulton_processing.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/fulton/fulton_processing.ipynb#Y155sZmlsZQ%3D%3D?line=0'>1</a> appended[appended['Situs Adrstr'].isna()].sample(1)
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\pandas\core\generic.py:5858, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5855 if weights is not None:
#    5856     weights = sample.preprocess_weights(self, weights, axis)
# -> 5858 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5859 result = self.take(sampled_indices, axis=axis)
#    5861 if ignore_index:
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\pandas\core\sample.py:151, in sample(obj_len, size, replace, weights, random_state)
#     148     else:
#     149         raise ValueError("Invalid weights: weights sum to zero")
# --> 151 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     152     np.intp, copy=False
#     153 )
#
# File mtrand.pyx:909, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %% [markdown]
# Let's also investigate NA examples of 'Owner Adrno', 'Owner Adrstr', 'Cityname.1', and 'Statecode'

# %%
appended[appended['Owner Adrno'].isna()].sample(2)
# Out:
#          Taxyr            Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 166542  2018.0  14 021500030520       1140.0          NaN   TUCKAWANNA
# 29503   2017.0  14 007100020656        235.0          NaN      HILLTOP
#
#        Situs Adrsuf Situs Adrsuf2 Cityname Class  Luc  Livunit Taxdist  \
# 166542           DR            SW  ATLANTA    R3  101      1.0       5
# 29503            DR            SW      ATL    R3  101      1.0       5
#
#                                     Own1 Own2  Owner Adrno Owner Adradd  \
# 166542              CHANEY FRANCES C MRS  NaN          NaN          NaN
# 29503   235 HILLTOP DRIVE LAND TRUST THE  NaN          NaN          NaN
#
#        Owner Adrdir   Owner Adrstr Owner Adrsuf Owner Adrsuf2  Cityname.1  \
# 166542          NaN   P.O. BOX 347          NaN           NaN  UNION CITY
# 29503           NaN  P.O. BOX 2327          NaN           NaN     ACWORTH
#
#        Statecode Country Unitno   Zip1 Reascd  Aprland  Aprbldg  Revcode  \
# 166542        GA     NaN    NaN  30291     FN  13300.0  52600.0      3.0
# 29503         GA     NaN    NaN  30102    NaN   5500.0  13000.0      3.0
#
#        Revreas   Aprtot  D Yrblt  D Effyr  D Yrremod D Grade    Sfla
# 166542     NaN  65900.0   1955.0      NaN        NaN       C  1662.0
# 29503      NaN  18500.0   1952.0      NaN     1970.0      C-  1308.0

# %% [markdown]
# Looks like empty Adrno might be when the owner uses a P.O. Box; we definitely want to keep these.

# %%
appended[appended['Owner Adrstr'].isna()].sample(2)
# Out:
#         Taxyr            Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 14333  2017.0  14 004000050081       1761.0          NaN     RICHMOND
# 43579  2017.0  14 011000100840        656.0          NaN     MAGNOLIA
#
#       Situs Adrsuf Situs Adrsuf2 Cityname Class  Luc  Livunit Taxdist  \
# 14333          AVE            SE      ATL    R3  101      1.0       5
# 43579           ST            NW      ATL    R3  100      0.0     05Z
#
#                    Own1 Own2  Owner Adrno Owner Adradd Owner Adrdir  \
# 14333  RESI SFR SUB LLC  NaN          NaN          NaN          NaN
# 43579  BELTEM TRUST THE  NaN          NaN          NaN          NaN
#
#       Owner Adrstr Owner Adrsuf Owner Adrsuf2     Cityname.1 Statecode  \
# 14333          NaN          NaN           NaN  CHRISTIANSTED        VI
# 43579          NaN          NaN           NaN            NaN       NaN
#
#               Country Unitno Zip1 Reascd  Aprland  Aprbldg  Revcode Revreas  \
# 14333   VIRGIN ISLAND    NaN  NaN    NaN   7100.0  37900.0      3.0      30
# 43579  UNITED KINGDOM    NaN  NaN    NaN   6500.0      0.0      NaN     NaN
#
#         Aprtot  D Yrblt  D Effyr  D Yrremod D Grade    Sfla
# 14333  45000.0   1920.0      NaN     2000.0       C  1035.0
# 43579   6500.0      NaN      NaN        NaN     NaN     NaN

# %% [markdown]
# Hard to determine anything. But we should just keep them for now.

# %%
appended[appended['Cityname.1'].isna()].sample(2)
# Out:
#          Taxyr            Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 142657  2018.0  14 014100061094        116.0          NaN   CHICAMAUGA
# 136308  2018.0  14 012100100680       1772.0          NaN      MELROSE
#
#        Situs Adrsuf Situs Adrsuf2 Cityname Class  Luc  Livunit Taxdist  \
# 142657          AVE            SW  ATLANTA    R3  101      1.0       5
# 136308           DR            SW  ATLANTA    R3  101      1.0       5
#
#                      Own1 Own2  Owner Adrno Owner Adradd Owner Adrdir  \
# 142657    CX HOLDINGS LLC  NaN          NaN          NaN          NaN
# 136308  ARLP REO 400  LLC  NaN          NaN          NaN          NaN
#
#        Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1 Statecode Country  \
# 142657          NaN          NaN           NaN        NaN       NaN   CHINA
# 136308          NaN          NaN           NaN        NaN       NaN     NaN
#
#        Unitno Zip1 Reascd  Aprland   Aprbldg  Revcode Revreas    Aprtot  \
# 142657    NaN  NaN     FN  11300.0   30100.0      3.0     NaN   41400.0
# 136308    NaN  NaN     E8  35400.0  142800.0      3.0     OVR  178200.0
#
#         D Yrblt  D Effyr  D Yrremod D Grade    Sfla
# 142657   1940.0      NaN        NaN      C-  2037.0
# 136308   1940.0   1985.0        NaN      C+  2371.0

# %% [markdown]
# Hard to determine anything. But we should just keep them for now.

# %%
appended[appended['Statecode'].isna()].sample(2)
# Out:
#         Taxyr            Parid  Situs Adrno Situs Adrdir   Situs Adrstr  \
# 54722  2017.0  14 014100040312        126.0          NaN     WELLINGTON
# 69056  2017.0  14 017900040499       2274.0          NaN  TIGER FLOWERS
#
#       Situs Adrsuf Situs Adrsuf2 Cityname Class  Luc  Livunit Taxdist  \
# 54722           ST            SW      ATL    R3  102      2.0       5
# 69056           DR            NW      ATL    R3  101      1.0       5
#
#                                        Own1 Own2  Owner Adrno Owner Adradd  \
# 54722                     ARLP REO 400  LLC  NaN          NaN          NaN
# 69056  STAMPER FAMILY SUPER INVESTMENTS LLC  NaN          NaN          NaN
#
#       Owner Adrdir Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1  \
# 54722          NaN          NaN          NaN           NaN        NaN
# 69056          NaN          NaN          NaN           NaN        NaN
#
#       Statecode Country Unitno Zip1 Reascd  Aprland  Aprbldg  Revcode Revreas  \
# 54722       NaN     NaN    NaN  NaN    NaN  10700.0  26400.0      NaN     NaN
# 69056       NaN     NaN    NaN  NaN    NaN   4900.0  33400.0      NaN     NaN
#
#         Aprtot  D Yrblt  D Effyr  D Yrremod D Grade    Sfla
# 54722  37100.0   1940.0      NaN        NaN      C-  1472.0
# 69056  38300.0   2008.0      NaN        NaN       C  2113.0

# %% [markdown]
# Many observations without Statecode appear to be in other countries.

# %% [markdown]
# There are not any major problems here, so let's just fill all NA with empty strings ''. We need to convert all these variables to strings first though.

# %%
print("Fill the above variables with empty strings when NA ---")

for v in check_vars:
    appended[v] = appended[v].astype('string').fillna('')
# Out:
# Fill the above variables with empty strings when NA ---

# %% [markdown]
# Construct the derived varibles

# %%
appended['site_addr'] = (
    appended['Situs Adrno'] + ' ' +
    appended['Situs Adrdir'] + ' ' +
    appended['Situs Adrstr'] + ' ' +
    appended['Situs Adrsuf'] + ' ' +
    appended['Situs Adrsuf2'] + ' ' +
    appended['Cityname']
)

# %%
appended['owner_addr'] = (
    appended['Owner Adrno'] + ' ' +
    appended['Owner Adrstr'] + ' ' +
    appended['Owner Adradd'] + ' ' +
    appended['Owner Adrdir'] + ' ' +
    appended['Owner Adrsuf'] + ' ' +
    appended['Owner Adrsuf2'] + ' ' +
    appended['Cityname.1'] + ' ' +
    appended['Statecode'] + ' ' +
    appended['Unitno']
)

# %% [markdown]
# Check the created variables look as expected

# %%
appended[['site_addr', 'owner_addr']].sample(5)
# Out:
#                                   site_addr  \
# 139686       1246.0  WESTMONT RD SW ATLANTA
# 23326              171.0  AUBURN AVE NE ATL
# 58099              1573.0  LAUREL PARK PL
# 156396         2210.0  BAKER TER NW ATLANTA
# 169126  3083.0  GREEN VALLEY DR  EAST POINT
#
#                                             owner_addr
# 139686             1246.0 WESTMONT   RD SW ATLANTA GA
# 23326   6301.0 OWENSMOUTH   AVE  WOODLAND HILLS CA 730
# 58099          1.0 ST PAUL   ST  ST. CATHARINES ON 100
# 156396              824.0 MEMORIAL   DR SE ATLANTA GA
# 169126        3083.0 GREEN VALLEY   DR  EAST POINT GA

# %% [markdown]
# Clean the decimal points from the numbers

# %%
appended['site_addr'] = appended['site_addr'].str.replace('.0','')

# %%
appended['owner_addr'] = appended['owner_addr'].str.replace('.0','')

# %%
appended[['site_addr', 'owner_addr']].sample(5)
# Out:
#                             site_addr                               owner_addr
# 109824   850  PIEDMONT AVE NE ATLANTA    850 PIEDMONT   AVE NE ATLANTA GA 1402
# 153172    1328  POLLARD DR SW ATLANTA  1388 HAIGHT   ST  SAN FRANCISCO CA #213
# 133993  254  HOLDERNESS ST SW ATLANTA    2912 CLOVERHURST   DR  EAST POINT GA
# 47492      1151  ARLINGTON AVE SW ATL           P O BOX 161922     ATLANTA GA
# 129656    1034  ALLENE AVE SW ATLANTA           P O BOX  2071     LITHONIA GA

# %% [markdown]
# Rename the variables and cast all the columns to the correct types

# %%
appended.rename(columns=new_var_map, inplace=True)

# %%
appended = appended[list(new_var_map.values())]

# %%
appended.columns
# Out:
# Index(['tax_year', 'parcel_id', 'site_addr', 'site_class_parcel',
#        'site_luc_parcel', 'tax_district', 'owner_name_1', 'owner_name_2',
#        'owner_zip', 'owner_addr', 'reas_cd', 'rev_code', 'rev_reas',
#        'appr_total', 'appr_land', 'appr_build', 'year_built', 'year_eff',
#        'year_remodel', 'grade', 'num_units', 'building_area'],
#       dtype='object')

# %% [markdown]
# When you try to cast, expect there to be problems. It is likely that some of the vars will have values that cannot be easily casted (e.g. 'A' cannot be casted to an Int). You will need to resolve these for each column.

# %%
appended = appended.astype(dtypes)

# %% [markdown]
# Clean nan values in 'owner_zip'

# %%
len(appended[appended['owner_zip'].isna()]) / len(appended) * 100
# Out:
# 0.4283829400777943

# %%
appended[appended['owner_zip'].isna()].sample(3)
# Out:
#         tax_year        parcel_id                          site_addr  \
# 63177     2017.0  14 016300120687               1895  DUNLAP AVE  EP
# 138637    2018.0  14 013300010059       1457  WADLEY AVE  EAST POINT
# 120370    2018.0  14 007900130788  400  WEST PEACHTREE ST NW ATLANTA
#
#        site_class_parcel site_luc_parcel tax_district  \
# 63177                 R3             107           20
# 138637                R3             101           20
# 120370                R3             106          05W
#
#                               owner_name_1 owner_name_2 owner_zip  \
# 63177   M&N FINE FUTURE INVESTMENTS GA LLC          NaN       NaN
# 138637                   ARLP REO 400  LLC          NaN       NaN
# 120370       SECRETARY OF VETERANS AFFAIRS          NaN       NaN
#
#                                  owner_addr reas_cd  rev_code rev_reas  \
# 63177                                           NaN       NaN      NaN
# 138637                                           E8       3.0       70
# 120370  3401 END  W AVE  NASHVILLE TN 760 W      FN       3.0      NaN
#
#         appr_total  appr_land  appr_build  year_built  year_eff  year_remodel  \
# 63177      41000.0     8000.0     33000.0      1968.0       NaN           NaN
# 138637    170500.0    27600.0    142900.0      1950.0    1988.0           NaN
# 120370    317400.0    40900.0    276500.0      2007.0       NaN           NaN
#
#        grade  num_units  building_area
# 63177     C-        1.0         1024.0
# 138637    C+        1.0         1472.0
# 120370     X        1.0         1127.0

# %% [markdown]
# It is an insignficant portion of the data, and quite important, so lets drop rows with None values for owner_zip

# %%
appended = appended[~appended['owner_zip'].isna()]

# %% [markdown]
# Let's investigate year_built

# %%
len(appended[appended['year_built'].isna()]) / len(appended) * 100
# Out:
# 11.94020432864674

# %% [markdown]
# Significant number of None values. Let's replace them with 0, and same for the other year columns.

# %%
appended['year_built'].fillna('0', inplace=True)
appended['year_eff'].fillna('0', inplace=True)
appended['year_remodel'].fillna('0', inplace=True)
# Out:
# C:\Users\nicho\AppData\Local\Temp\ipykernel_18240\3972586776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   appended['year_built'].fillna('0', inplace=True)
# C:\Users\nicho\AppData\Local\Temp\ipykernel_18240\3972586776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   appended['year_eff'].fillna('0', inplace=True)
# C:\Users\nicho\AppData\Local\Temp\ipykernel_18240\3972586776.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   appended['year_remodel'].fillna('0', inplace=True)

# %% [markdown]
# Investigate 'num_units'

# %%
len(appended[appended['num_units'].isna()]) / len(appended) * 100
# Out:
# 0.21855478497306785

# %%
appended[appended['num_units'].isna()].sample(5)
# Out:
#         tax_year        parcel_id                         site_addr  \
# 104004    2018.0  14 0045  LL1130        170  BOULEVARD  SE ATLANTA
# 50962     2017.0  14 013300020272                 0  WADLEY AVE  EP
# 130332    2018.0  14 0108  LL2421            898  OAK ST SW ATLANTA
# 43675     2017.0  14 011100010808  533  JOSEPH E LOWERY BLVD NW ATL
# 33547     2017.0  14 008300040411            534  SPENCER ST NW ATL
#
#        site_class_parcel site_luc_parcel tax_district  \
# 104004                R3             106          05W
# 50962                 E1             600           20
# 130332                R3             106          05T
# 43675                 R3             100          05Z
# 33547                 R3             100          05Z
#
#                         owner_name_1 owner_name_2 owner_zip  \
# 104004                   BOWER EVE W          NaN     30312
# 50962                          MARTA          NaN     30308
# 130332               MUHAMMAD RABB O          NaN     30310
# 43675   CANOPY DEVELOPMENT GROUP LLC          NaN     30325
# 33547            NEF ENTERPRISES LLC          NaN     30328
#
#                                      owner_addr reas_cd  rev_code rev_reas  \
# 104004     170 BOULEVARD    SE ATLANTA GA H-327      FN       3.0      NaN
# 50962        401 PEACHTREE  W ST NW ATLANTA GA      NaN       1.0       20
# 130332          898 OAK   ST SW ATLANTA GA 3417      FN       3.0      NaN
# 43675             P O BOX 19696     ATLANTA GA        0       NaN      NaN
# 33547   7095 NORTHGREEN   DR  SANDY SPRINGS GA      NaN       NaN      NaN
#
#         appr_total  appr_land  appr_build year_built year_eff year_remodel  \
# 104004    250400.0    26200.0    224200.0     1910.0   1985.0            0
# 50962      13300.0    13300.0         0.0          0        0            0
# 130332     97900.0    13000.0     84900.0     2007.0        0            0
# 43675       3900.0     3900.0         0.0          0        0            0
# 33547       6300.0     6300.0         0.0          0        0            0
#
#        grade  num_units  building_area
# 104004    B+        NaN          995.0
# 50962    NaN        NaN            NaN
# 130332    B+        NaN         1019.0
# 43675    NaN        NaN            NaN
# 33547    NaN        NaN            NaN

# %% [markdown]
# Let's fill these with 0.

# %%
appended['num_units'].fillna('0', inplace=True)

# %% [markdown]
# Check the datatypes

# %%
appended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174327 entries, 0 to 175076
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tax_year           174327 non-null  int16
#  1   parcel_id          174327 non-null  string
#  2   site_addr          174327 non-null  string
#  3   site_class_parcel  174327 non-null  category
#  4   site_luc_parcel    174327 non-null  category
#  5   tax_district       174327 non-null  category
#  6   owner_name_1       174327 non-null  string
#  7   owner_name_2       19943 non-null   string
#  8   owner_zip          174327 non-null  string
#  9   owner_addr         174327 non-null  string
#  10  reas_cd            100349 non-null  string
#  11  rev_code           109046 non-null  string
#  12  rev_reas           26241 non-null   string
#  13  appr_total         174327 non-null  float32
#  14  appr_land          174327 non-null  float32
#  15  appr_build         174127 non-null  float32
#  16  year_built         174327 non-null  int16
#  17  year_eff           174327 non-null  int16
#  18  year_remodel       174327 non-null  int16
#  19  grade              153508 non-null  category
#  20  num_units          174327 non-null  int16
#  21  building_area      153513 non-null  float32
# dtypes: category(4), float32(4), int16(5), string(9)
# memory usage: 18.3 MB

# %% [markdown]
# Export the data

# %%
appended.to_csv('../output/all_parcels_fulton_2011_2022.csv')
appended.to_parquet('../output/all_parcels_fulton_2011_2022.parquet')
