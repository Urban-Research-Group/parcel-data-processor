# %% [markdown]
# # Fulton Parcel Processing

# %%
import pandas as pd
import os

pd.set_option('display.max_columns', None)

# %%
# Original names of variables, include these on data format sheet
original_vars = [
    'Taxyr', 'Parid', 'Situs Adrno', 'Situs Adrdir',
    'Situs Adrstr', 'Situs Adrsuf', 'Situs Adrsuf2',
    'Cityname', 'Class', 'Luc', 'Livunit',
    'Taxdist', 'Own1', 'Own2', 'Owner Adrno',
    'Owner Adradd', 'Owner Adrdir', 'Owner Adrstr',
    'Owner Adrsuf', 'Owner Adrsuf2', 'Cityname.1',
    'Statecode', 'Country', 'Unitno', 'Zip1', 'Reascd',
    'Aprland', 'Aprbldg', 'Revcode', 'Revreas', 'Aprtot',
    'D Yrblt', 'D Effyr', 'D Yrremod', 'D Grade', 'Sfla'
]
# New names of variables, 'final variable name' on data format sheet
new_var_map = {
    'Taxyr': 'tax_year', 'Parid': 'parcel_id', 'site_addr': 'site_addr',
    'Class': 'site_class_parcel', 'Luc': 'site_luc_parcel',
    'Taxdist': 'tax_district', 'Own1': 'owner_name_1', 
    'Own2': 'owner_name_2', 'Zip1': 'owner_zip', 'owner_addr': 'owner_addr',
    'Reascd': 'reas_cd', 'Revcode': 'rev_code',
    'Revreas': 'rev_reas', 'Aprtot': 'appr_total',
    'Aprland': 'appr_land', 'Aprbldg': 'appr_build', 'D Yrblt': 'year_built',
    'D Effyr': 'year_eff', 'D Yrremod': 'year_remodel', 'D Grade': 'grade',
    'Livunit': 'num_units', 'Sfla': 'building_area'
}
# New variable names ('final variable name' on data format sheet)
# with their associated datatype mapping
dtypes = {
    'tax_year': 'int16', 'parcel_id': 'string', 'site_addr': 'string',
    'site_class_parcel': 'string', 'site_luc_parcel': 'string',
    'tax_district': 'string', 'owner_name_1': 'string',
    'owner_name_2': 'string', 'owner_zip': 'string', 'owner_addr': 'string',
    'reas_cd': 'string', 'rev_code': 'string', 'rev_reas': 'string',
    'appr_total': 'float32', 'appr_land': 'float32', 'appr_build': 'float32',
    'year_built': 'int16', 'year_eff': 'int16',
    'year_remodel': 'int16', 'grade': 'string',
    'num_units': 'int16', 'building_area': 'float32'
}

# %% [markdown]
# ## Read in Files

# %% [markdown]
# Get all file names in directory.

# %%
prefix_path = '../data/fulton/parcels/'
file_paths = os.listdir(prefix_path)
total_files = len(file_paths)
file_paths[:2] # printing out the first 2 files
# Out:
# ['14_2010-2011.xlsx', '14_2012-2013.xlsx']

# %% [markdown]
# Loop through files and read them in. Store them in a list of dataframes. appendeded on a single file first.

# %%
dfs = []
count = 0

for file in file_paths:
    print(f'{count} / {total_files}')
    dfs.append(
        pd.read_excel(prefix_path + file)
    )
    count += 1
# Out:
# 0 / 53
# 1 / 53
# 2 / 53
# 3 / 53
# 4 / 53
# 5 / 53
# 6 / 53
# 7 / 53
# 8 / 53
# 9 / 53
# 10 / 53
# 11 / 53
# 12 / 53
# 13 / 53
# 14 / 53
# 15 / 53
# 16 / 53
# 17 / 53
# 18 / 53
# 19 / 53
# 20 / 53
# 21 / 53
# 22 / 53
# 23 / 53
# 24 / 53
# 25 / 53
# 26 / 53
# 27 / 53
# 28 / 53
# 29 / 53
# 30 / 53
# 31 / 53
# 32 / 53
# 33 / 53
# 34 / 53
# 35 / 53
# 36 / 53
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\nicho\Documents\research\ga-tax-assessment\fulton\fulton_processing.ipynb Cell 8 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/fulton/fulton_processing.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> for file in file_paths:
#       <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/fulton/fulton_processing.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     print(f'{count} / {total_files}')
#       <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/fulton/fulton_processing.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     dfs.append(
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/fulton/fulton_processing.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>         pd.read_excel(prefix_path + file)
#       <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/fulton/fulton_processing.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>     )
#       <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/fulton/fulton_processing.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a>     count += 1
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\pandas\io\excel\_base.py:486, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#     485 try:
# --> 486     data = io.parse(
#     487         sheet_name=sheet_name,
#     488         header=header,
#     489         names=names,
#     490         index_col=index_col,
#     491         usecols=usecols,
#     492         dtype=dtype,
#     493         converters=converters,
#     494         true_values=true_values,
#     495         false_values=false_values,
#     496         skiprows=skiprows,
#     497         nrows=nrows,
#     498         na_values=na_values,
#     499         keep_default_na=keep_default_na,
#     500         na_filter=na_filter,
#     501         verbose=verbose,
#     502         parse_dates=parse_dates,
#     503         date_parser=date_parser,
#     504         date_format=date_format,
#     505         thousands=thousands,
#     506         decimal=decimal,
#     507         comment=comment,
#     508         skipfooter=skipfooter,
#     509         dtype_backend=dtype_backend,
#     510     )
#     511 finally:
#     512     # make sure to close opened file handles
#     513     if should_close:
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\pandas\io\excel\_base.py:1551, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1518 def parse(
#    1519     self,
#    1520     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1538     **kwds,
#    1539 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1540     """
#    1541     Parse specified sheet(s) into a DataFrame.
#    1542
#    (...)
#    1549         DataFrame from the passed in Excel file.
#    1550     """
# -> 1551     return self._reader.parse(
#    1552         sheet_name=sheet_name,
#    1553         header=header,
#    1554         names=names,
#    1555         index_col=index_col,
#    1556         usecols=usecols,
#    1557         converters=converters,
#    1558         true_values=true_values,
#    1559         false_values=false_values,
#    1560         skiprows=skiprows,
#    1561         nrows=nrows,
#    1562         na_values=na_values,
#    1563         parse_dates=parse_dates,
#    1564         date_parser=date_parser,
#    1565         date_format=date_format,
#    1566         thousands=thousands,
#    1567         comment=comment,
#    1568         skipfooter=skipfooter,
#    1569         dtype_backend=dtype_backend,
#    1570         **kwds,
#    1571     )
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\pandas\io\excel\_base.py:751, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     748     sheet = self.get_sheet_by_index(asheetname)
#     750 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 751 data = self.get_sheet_data(sheet, file_rows_needed)
#     752 if hasattr(sheet, "close"):
#     753     # pyxlsb opens two TemporaryFiles
#     754     sheet.close()
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\pandas\io\excel\_openpyxl.py:602, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     600 data: list[list[Scalar]] = []
#     601 last_row_with_data = -1
# --> 602 for row_number, row in enumerate(sheet.rows):
#     603     converted_row = [self._convert_cell(cell) for cell in row]
#     604     while converted_row and converted_row[-1] == "":
#     605         # trim trailing empty elements
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\openpyxl\worksheet\_read_only.py:81, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77 src = self._get_source()
#      78 parser = WorkSheetParser(src, self._shared_strings,
#      79                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      80                          date_formats=self.parent._date_formats)
# ---> 81 for idx, row in parser.parse():
#      82     if max_row is not None and idx > max_row:
#      83         break
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\openpyxl\worksheet\_reader.py:156, in WorkSheetParser.parse(self)
#     137 properties = {
#     138     PRINT_TAG: ('print_options', PrintOptions),
#     139     MARGINS_TAG: ('page_margins', PageMargins),
#    (...)
#     151
#     152 }
#     154 it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
# --> 156 for _, element in it:
#     157     tag_name = element.tag
#     158     if tag_name in dispatcher:
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\xml\etree\ElementTree.py:1251, in iterparse.<locals>.iterator(source)
#    1249 yield from pullparser.read_events()
#    1250 # load event buffer
# -> 1251 data = source.read(16 * 1024)
#    1252 if not data:
#    1253     break
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\zipfile.py:955, in ZipExtFile.read(self, n)
#     953 self._offset = 0
#     954 while n > 0 and not self._eof:
# --> 955     data = self._read1(n)
#     956     if n < len(data):
#     957         self._readbuffer = data
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\zipfile.py:1045, in ZipExtFile._read1(self, n)
#    1043 if self._left <= 0:
#    1044     self._eof = True
# -> 1045 self._update_crc(data)
#    1046 return data
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\zipfile.py:970, in ZipExtFile._update_crc(self, newdata)
#     967 if self._expected_crc is None:
#     968     # No need to compute the CRC if we don't have a reference value
#     969     return
# --> 970 self._running_crc = crc32(newdata, self._running_crc)
#     971 # Check the CRC if we're at the end of the file
#     972 if self._eof and self._running_crc != self._expected_crc:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Append Files

# %% [markdown]
# Dropping extra vars.
#
# Recommend dropping uneeded variables first if data size is large; the best way to do this is by only keeping variables we need because we don't need many.
#
# We also want to remove the last row of each file (for Fulton, at least), because it simply contains a 'Count Distinct' value in the source data- this is not something we want.

# %%
# Calculating total num of rows to verify next step
total_rows = 0

for index, df in enumerate(dfs):
    init = len(df.columns)
    dfs[index] = df[original_vars][:-1]
    total_rows += len(df)
    print(f'Dropped {init - len(df.columns)} columns')
# Out:
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns
# Dropped 0 columns

# %% [markdown]
# Now all dfs should have the same columns. We can append.

# %%
appended = pd.concat(dfs, ignore_index=True)

init_size = len(appended) # Take inital size of data for later calc

print(f'Appended has {len(appended)} rows; total rows calculated '
      + f'previously is {total_rows}')
# Out:
# Appended has 5986515 rows; total rows calculated previously is 5986568

# %% [markdown]
# Construct the derived variables (e.g. site_addr from the multiple site address variables in this data). However, before we can do this, we need to clean each of the columns we will join to create this variable.
#
# More specifically, we need check how many None values there are in each column, then replace them with something that makes sense. This is because if you try to add a row with value None for one column (say address num) and "Main Street" for another, the result will be None.

# %%
check_vars = ['Situs Adrno', 'Situs Adrdir','Situs Adrstr',
              'Situs Adrsuf', 'Situs Adrsuf2', 'Cityname',
              'Owner Adrno', 'Owner Adrstr', 'Owner Adradd',
              'Owner Adrdir', 'Owner Adrsuf', 'Owner Adrsuf2',
              'Cityname.1', 'Statecode', 'Unitno']

print("Percent NA by Variable ---")
for v in check_vars:
    pct_na = len(appended[appended[v].isna()]) / len(appended)* 100
    print(f'{v}: {pct_na:.2f}')
# Out:
# Percent NA by Variable ---
# Situs Adrno: 0.01
# Situs Adrdir: 99.94
# Situs Adrstr: 0.00
# Situs Adrsuf: 5.59
# Situs Adrsuf2: 48.49
# Cityname: 0.42
# Owner Adrno: 4.02
# Owner Adrstr: 0.42
# Owner Adradd: 99.66
# Owner Adrdir: 96.87
# Owner Adrsuf: 8.39
# Owner Adrsuf2: 61.92
# Cityname.1: 0.40
# Statecode: 0.41
# Unitno: 80.62

# %% [markdown]
# Let's investigate some examples of NA for Cityname because, while insignificant, it is an important column.

# %%
appended[appended['Cityname'].isna()].sample(2)
# Out:
#           Taxyr            Parid  Situs Adrno Situs Adrdir  Situs Adrstr  \
# 1562315  2016.0  17 010900051023        140.0          NaN         ALDEN
# 5588981  2017.0  09F250201061526       5533.0          NaN  WAVERLY PARK
#
#         Situs Adrsuf Situs Adrsuf2 Cityname Class    Luc Livunit Taxdist  \
# 1562315          AVE            NW      NaN    R3  106.0     1.0       5
# 5588981          NaN           NaN      NaN    R3  100.0     1.0      55
#
#                                      Own1 Own2  Owner Adrno Owner Adradd  \
# 1562315  AMERICAN FREEDOM INVESTMENTS LLC  NaN       2221.0          NaN
# 5588981                    D R HORTON INC  NaN          NaN          NaN
#
#         Owner Adrdir    Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1  \
# 1562315          NaN       PEACHTREE           RD            NE    ATLANTA
# 5588981          NaN  P O BOX 422357          NaN           NaN    ATLANTA
#
#         Statecode Country Unitno   Zip1 Reascd  Aprland   Aprbldg  Revcode  \
# 1562315        GA     NaN   D106  30309    NaN  34600.0  124700.0      NaN
# 5588981        GA     NaN    NaN  30342    NaN  12000.0       0.0      3.0
#
#         Revreas    Aprtot  D Yrblt  D Effyr  D Yrremod D Grade   Sfla
# 1562315     NaN  159300.0   2006.0      NaN        NaN      A-  827.0
# 5588981     NaN   12000.0      NaN      NaN        NaN     NaN    NaN

# %%
appended[appended['Situs Adrstr'].isna()].sample(1)
# Out:
#           Taxyr            Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 2407906  2014.0  14 0029  LL0421          0.0          NaN          NaN
#
#         Situs Adrsuf Situs Adrsuf2 Cityname Class  Luc Livunit Taxdist  \
# 2407906           RD            SE  ATLANTA    C4  300     0.0       5
#
#                               Own1 Own2  Owner Adrno Owner Adradd  \
# 2407906  COOGLER SUSIE ALICE EXTRX  NaN       2780.0          NaN
#
#         Owner Adrdir Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1  \
# 2407906          NaN    JONESBORO           RD            SE    ATLANTA
#
#         Statecode Country Unitno   Zip1 Reascd   Aprland  Aprbldg  Revcode  \
# 2407906        GA     NaN    NaN  30354    NaN  149500.0      0.0      NaN
#
#         Revreas    Aprtot  D Yrblt  D Effyr  D Yrremod D Grade  Sfla
# 2407906     NaN  149500.0      NaN      NaN        NaN     NaN   NaN

# %% [markdown]
# Let's also investigate NA examples of 'Owner Adrno', 'Owner Adrstr', 'Cityname.1', and 'Statecode'

# %%
appended[appended['Owner Adrno'].isna()].sample(2)
# Out:
#           Taxyr            Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 1740118  2018.0  17 018600061309          0.0          NaN     BRICKTON
# 5183149  2011.0  13 0193  LL1264       7529.0          NaN      BOWHEAD
#
#         Situs Adrsuf Situs Adrsuf2 Cityname Class    Luc Livunit Taxdist  \
# 1740118           DR           NaN  ATLANTA    R3  100.0     0.0       5
# 5183149           CT           NaN      FUL    R3  100.0     0.0      55
#
#                                 Own1 Own2  Owner Adrno Owner Adradd  \
# 1740118    FIRST CHOICE BUILDERS INC  NaN          NaN          NaN
# 5183149  LEGACY INVESTMENT GROUP LLC  NaN          NaN          NaN
#
#         Owner Adrdir     Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1  \
# 1740118          NaN  P.O. BOX 250214          NaN           NaN    ATLANTA
# 5183149          NaN   P O BOX 191588          NaN           NaN    ATLANTA
#
#         Statecode Country Unitno   Zip1 Reascd  Aprland  Aprbldg  Revcode  \
# 1740118        GA     NaN    NaN  30325     FN    100.0      0.0      3.0
# 5183149        GA     NaN    NaN  31119     E1   7300.0      0.0      3.0
#
#         Revreas  Aprtot  D Yrblt  D Effyr  D Yrremod D Grade  Sfla
# 1740118     NaN   100.0      NaN      NaN        NaN     NaN   NaN
# 5183149     OVR  7300.0      NaN      NaN        NaN     NaN   NaN

# %% [markdown]
# Looks like empty Adrno might be when the owner uses a P.O. Box; we definitely want to keep these.

# %%
appended[appended['Owner Adrstr'].isna()].sample(2)
# Out:
#           Taxyr            Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 3795861  2022.0  14 008700010691          0.0          NaN         MARY
# 5677411  2018.0  13 0133  LL4881       2250.0          NaN      BIGWOOD
#
#         Situs Adrsuf Situs Adrsuf2      Cityname Class    Luc Livunit Taxdist  \
# 3795861           ST            SW       ATLANTA    R3    100     0.0       5
# 5677411          TRL           NaN  SOUTH FULTON    R3  107.0     1.0      55
#
#                                      Own1 Own2  Owner Adrno Owner Adradd  \
# 3795861  PITTSBURGH COMMUNITY HOUSING LLC  NaN          NaN          NaN
# 5677411          RAVEN PROPERTY GROUP LLC  NaN          NaN          NaN
#
#         Owner Adrdir Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1  \
# 3795861          NaN          NaN          NaN           NaN        NaN
# 5677411          NaN          NaN          NaN           NaN        NaN
#
#         Statecode         Country Unitno Zip1 Reascd  Aprland  Aprbldg  \
# 3795861       NaN             NaN    NaN  NaN    NaN  68400.0      0.0
# 5677411       NaN  UNITED KINGDOM    NaN  NaN     FN  13500.0  58000.0
#
#          Revcode Revreas   Aprtot  D Yrblt  D Effyr  D Yrremod D Grade    Sfla
# 3795861      1.0      20  68400.0      NaN      NaN        NaN     NaN     NaN
# 5677411      3.0     NaN  71500.0   2008.0      NaN        NaN       C  1660.0

# %% [markdown]
# Hard to determine anything. But we should just keep them for now.

# %%
appended[appended['Cityname.1'].isna()].sample(2)
# Out:
#           Taxyr                 Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 3061279  2017.0  14F0012  LL0283U0268        405.0          NaN     FAIRBURN
# 2857551  2016.0       14 007500040346        723.0          NaN     FORMWALT
#
#         Situs Adrsuf Situs Adrsuf2 Cityname Class  Luc Livunit Taxdist  \
# 3061279           RD            SW      NaN    C3  208     NaN       5
# 2857551           ST            SW      ATL    R3  101     1.0       5
#
#                    Own1 Own2  Owner Adrno Owner Adradd Owner Adrdir  \
# 3061279  WILDWOOD PARK   NaN          NaN          NaN          NaN
# 2857551    NEROKGSG LLC  NaN          NaN          NaN          NaN
#
#         Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1 Statecode  Country  \
# 3061279          NaN          NaN           NaN        NaN       NaN      NaN
# 2857551          NaN          NaN           NaN        NaN       NaN  BELGIUM
#
#         Unitno Zip1 Reascd  Aprland  Aprbldg  Revcode Revreas   Aprtot  \
# 3061279    268  NaN    NaN  10900.0  17300.0      NaN     NaN  28200.0
# 2857551    NaN  NaN    NaN  11600.0  43300.0      NaN     NaN  54900.0
#
#          D Yrblt  D Effyr  D Yrremod D Grade    Sfla
# 3061279   2007.0      NaN        NaN     NaN     0.0
# 2857551   2004.0      NaN        NaN       C  1806.0

# %% [markdown]
# Hard to determine anything. But we should just keep them for now.

# %%
appended[appended['Statecode'].isna()].sample(2)
# Out:
#           Taxyr                 Parid  Situs Adrno Situs Adrdir Situs Adrstr  \
# 2104905  2012.0  14 003500010447U0061       2980.0          NaN    JONESBORO
# 66051    2011.0       14 008200030579        490.0          NaN     MARIETTA
#
#         Situs Adrsuf Situs Adrsuf2 Cityname Class  Luc Livunit Taxdist  \
# 2104905           RD            SE      NaN    C3  208     NaN       5
# 66051             ST            NW  ATLANTA    R3  110     1.0     05Z
#
#                           Own1 Own2  Owner Adrno Owner Adradd Owner Adrdir  \
# 2104905         OXFORD VILLAGE  NaN          NaN          NaN          NaN
# 66051    ROBINSON CHEYNEY LYNN  NaN          NaN          NaN          NaN
#
#         Owner Adrstr Owner Adrsuf Owner Adrsuf2 Cityname.1 Statecode Country  \
# 2104905          NaN          NaN           NaN        NaN       NaN     NaN
# 66051            NaN          NaN           NaN        NaN       NaN      UK
#
#         Unitno Zip1 Reascd  Aprland   Aprbldg  Revcode Revreas    Aprtot  \
# 2104905     61  NaN    NaN  16300.0   12100.0      1.0      CP   28400.0
# 66051      NaN  NaN    NaN  39000.0  134900.0      1.0      20  173900.0
#
#          D Yrblt  D Effyr  D Yrremod D Grade    Sfla
# 2104905   2007.0      NaN        NaN     NaN     0.0
# 66051     1945.0   1990.0     1997.0      B+  1069.0

# %% [markdown]
# Many observations without Statecode appear to be in other countries.

# %% [markdown]
# There are not any major problems here, so let's just fill all NA with empty strings ''. We need to convert all these variables to strings first though.

# %%
print("Fill the above variables with empty strings when NA ---")

for v in check_vars:
    appended[v] = appended[v].astype('string').fillna('')
# Out:
# Fill the above variables with empty strings when NA ---

# %% [markdown]
# Construct the derived varibles

# %%
appended['site_addr'] = (
    appended['Situs Adrno'] + ' ' +
    appended['Situs Adrdir'] + ' ' +
    appended['Situs Adrstr'] + ' ' +
    appended['Situs Adrsuf'] + ' ' +
    appended['Situs Adrsuf2'] + ' ' +
    appended['Cityname']
)

# %%
appended['owner_addr'] = (
    appended['Owner Adrno'] + ' ' +
    appended['Owner Adrstr'] + ' ' +
    #appended['Cityname.1'] + ' ' +
    #appended['Statecode'] + ' ' +
    appended['Unitno']
)

# %% [markdown]
# Check the created variables look as expected

# %%
appended[['site_addr', 'owner_addr']].sample(5)
# Out:
#                                 site_addr            owner_addr
# 3453590      751.0  CUSTER AVE SE ATLANTA         751.0 CUSTER
# 5715891  0.0  FAYETTEVILLE RD  UNION CITY        7300.0 LESTER
# 40028        860.0  PEACHTREE ST  ATLANTA  1101.0 UNIVERSITY #4
# 382973         352.0  GLENN ST SW ATLANTA        117.0 OAKWIND
# 669428    1555.0  OLYMPIAN WAY SW ATLANTA

# %% [markdown]
# Clean the decimal points from the numbers

# %%
appended['site_addr'] = appended['site_addr'].str.replace('.0','')

# %%
appended['owner_addr'] = appended['owner_addr'].str.replace('.0','')

# %%
appended[['site_addr', 'owner_addr']].sample(5)
# Out:
#                             site_addr          owner_addr
# 2247887   3827  COLLIER DR NW ATLANTA       3827 COLLIER
# 4487404    745  FALLING ROCKS CT  ROS  745 FALLING ROCKS
# 1703842  115  MARK TRL  SANDY SPRINGS           115 MARK
# 3946870      0  BUICE RD  JOHNS CREEK         5050 BUICE
# 540908       584  GLEN IRIS DR NE ATL      584 GLEN IRIS

# %% [markdown]
# Rename the variables and cast all the columns to the correct types

# %%
appended.rename(columns=new_var_map, inplace=True)

# %%
appended = appended[list(new_var_map.values())]

# %%
appended.columns
# Out:
# Index(['tax_year', 'parcel_id', 'site_addr', 'site_class_parcel',
#        'site_luc_parcel', 'tax_district', 'owner_name_1', 'owner_name_2',
#        'owner_zip', 'owner_addr', 'reas_cd', 'rev_code', 'rev_reas',
#        'appr_total', 'appr_land', 'appr_build', 'year_built', 'year_eff',
#        'year_remodel', 'grade', 'num_units', 'building_area'],
#       dtype='object')

# %% [markdown]
# When you try to cast, expect there to be problems. It is likely that some of the vars will have values that cannot be easily casted (e.g. 'A' cannot be casted to an Int). You will need to resolve these for each column.

# %%
#appended = appended.astype(dtypes)

# %% [markdown]
# Clean nan values in 'owner_zip'

# %%
len(appended[appended['owner_zip'].isna()]) / len(appended) * 100
# Out:
# 0.4649616680155315

# %%
appended[appended['owner_zip'].isna()].sample(3)
# Out:
#         tax_year             parcel_id             site_addr  \
# 2907694   2016.0  14F0012  LL0234U0088  400  FAIRBURN RD SW
# 3035766   2017.0       14 014400010023   0  ELINOR PL NW ATL
# 2550625   2013.0  14F0012  LL0283U0239  405  FAIRBURN RD SW
#
#         site_class_parcel site_luc_parcel tax_district         owner_name_1  \
# 2907694                C3             208            5  FAIRBURN TOWNHOUSES
# 3035766                R3             100            5     BROWN LINA W MRS
# 2550625                C3             208            5       WILDWOOD PARK
#
#         owner_name_2 owner_zip owner_addr reas_cd  rev_code rev_reas  \
# 2907694          NaN       NaN         88     NaN       NaN      NaN
# 3035766          NaN       NaN                NaN       NaN      NaN
# 2550625          NaN       NaN        239     NaN       1.0       CP
#
#          appr_total  appr_land  appr_build  year_built  year_eff  \
# 2907694     28700.0    16700.0     12000.0      2007.0       NaN
# 3035766     16200.0    16200.0         0.0         NaN       NaN
# 2550625     30600.0    12800.0     17800.0      2007.0       NaN
#
#          year_remodel grade num_units  building_area
# 2907694           NaN   NaN       NaN            0.0
# 3035766           NaN   NaN       0.0            NaN
# 2550625           NaN   NaN       NaN            0.0

# %% [markdown]
# It is an insignficant portion of the data, and quite important, so lets drop rows with None values for owner_zip

# %%
#appended = appended[~appended['owner_zip'].isna()]
appended['owner_zip'].fillna('0', inplace=True)

# %% [markdown]
# Let's investigate year_built

# %%
len(appended[appended['year_built'].isna()]) / len(appended) * 100
# Out:
# 12.287349150549193

# %% [markdown]
# Significant number of None values. Let's replace them with 0, and same for the other year columns.

# %%
appended['year_built'].fillna('0', inplace=True)
appended['year_eff'].fillna('0', inplace=True)
appended['year_remodel'].fillna('0', inplace=True)

# %% [markdown]
# Investigate 'num_units'

# %%
len(appended[appended['num_units'].isna()]) / len(appended) * 100
# Out:
# 0.9317440948531825

# %%
appended[appended['num_units'].isna()].sample(5)
# Out:
#         tax_year             parcel_id                      site_addr  \
# 2130919   2011.0       14 005400040242      0  CAPITOL AVE SE ATLANTA
# 1906303   2020.0       17 0221  LL2863    1377  LIBERTY PKWY  ATLANTA
# 3767533   2022.0  14 0029  LL0454U0298  2980  JONESBORO RD SE ATLANTA
# 912251    2021.0       14 009000011231         0  GRANT ST SW ATLANTA
# 2550842   2014.0  14F0012  LL0291U0197           400  FAIRBURN RD SW
#
#         site_class_parcel site_luc_parcel tax_district           owner_name_1  \
# 2130919                C3             339          05P      DELTA PARKING INC
# 1906303                R3           107.0            5          PINCU DOUGLAS
# 3767533                C3             208            5         OXFORD VILLAGE
# 912251                 R3           100.0          05R   SMITH ROBERT FLOYD &
# 2550842                C3             208            5  FAIRBURN TOWNE HOUSES
#
#           owner_name_2 owner_zip      owner_addr reas_cd  rev_code rev_reas  \
# 2130919            NaN     30324  1024 LINDBERG      NaN       3.0       80
# 1906303            NaN     30318   1377 LIBERTY       RF       NaN      NaN
# 3767533            NaN         0             298     NaN       NaN      NaN
# 912251   THOMAS NICOLE     30252  126 PINEHAVEN      NaN       NaN      NaN
# 2550842            NaN         0             197     NaN       1.0       CP
#
#          appr_total  appr_land  appr_build year_built year_eff year_remodel  \
# 2130919     74600.0    65600.0      9000.0          0        0            0
# 1906303    280900.0    42300.0    238600.0     2006.0        0            0
# 3767533     17800.0        0.0     17800.0     2007.0        0            0
# 912251      97200.0    97200.0         0.0          0        0            0
# 2550842     32300.0     1400.0     30900.0     2007.0        0            0
#
#         grade num_units  building_area
# 2130919   NaN       NaN            NaN
# 1906303     B       NaN         1326.0
# 3767533   NaN       NaN            0.0
# 912251    NaN       NaN            NaN
# 2550842   NaN       NaN            0.0

# %% [markdown]
# Let's fill these with 0.

# %%
appended['num_units'].fillna('0', inplace=True)

# %%
appended = appended[appended['tax_year'].str.count("([a-zA-Z])") <= 1]

# %%
appended = appended.astype(dtypes)

# %% [markdown]
# Check the datatypes

# %%
appended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tax_year           0 non-null      int16
#  1   parcel_id          0 non-null      string
#  2   site_addr          0 non-null      string
#  3   site_class_parcel  0 non-null      string
#  4   site_luc_parcel    0 non-null      string
#  5   tax_district       0 non-null      string
#  6   owner_name_1       0 non-null      string
#  7   owner_name_2       0 non-null      string
#  8   owner_zip          0 non-null      string
#  9   owner_addr         0 non-null      string
#  10  reas_cd            0 non-null      string
#  11  rev_code           0 non-null      string
#  12  rev_reas           0 non-null      string
#  13  appr_total         0 non-null      float32
#  14  appr_land          0 non-null      float32
#  15  appr_build         0 non-null      float32
#  16  year_built         0 non-null      int16
#  17  year_eff           0 non-null      int16
#  18  year_remodel       0 non-null      int16
#  19  grade              0 non-null      string
#  20  num_units          0 non-null      int16
#  21  building_area      0 non-null      float32
# dtypes: float32(4), int16(5), string(13)
# memory usage: 0.0 bytes

# %% [markdown]
# Export the data

# %%
appended.to_csv('../output/all_parcels_fulton_2011_2022.csv')
appended.to_parquet('../output/all_parcels_fulton_2011_2022.parquet')
