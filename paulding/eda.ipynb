# %%
import polars as pl
import pandas as pd
from PyPDF2 import PdfReader
import textract
from pdf2image import convert_from_path
import docx2txt
from PIL import Image
from textractor import Textractor
from textractor.data.constants import TextractFeatures
import re

# %%
extractor = Textractor(profile_name="default")

# %%
Image.open(convert_from_path("../data/paulding/parcels/2011 DIGEST VENDOR FILES/Record_Layout_Paulding_Georgia.pdf"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\PIL\Image.py:3240, in open(fp, mode, formats)
#    3239 try:
# -> 3240     fp.seek(0)
#    3241 except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'list' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\Users\nicho\Documents\research\ga-tax-assessment\paulding\eda.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/paulding/eda.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> Image.open(convert_from_path("../data/paulding/parcels/2011 DIGEST VENDOR FILES/Record_Layout_Paulding_Georgia.pdf"))
#
# ...

# %%
document = extractor.analyze_document(
    file_source=Image.open('../data/paulding/parcels/2011 DIGEST VENDOR FILES/Record_Layout_Paulding_Georgia.pdf'),
    features=[TextractFeatures.FORMS, TextractFeatures.TABLES],
    save_image=True,
)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# c:\Users\nicho\Documents\research\ga-tax-assessment\paulding\eda.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/paulding/eda.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> document = extractor.analyze_document(
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/paulding/eda.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     file_source=Image.open('../data/paulding/parcels/2011 DIGEST VENDOR FILES/Record_Layout_Paulding_Georgia.pdf'),
#       <a href='vscode-notebook-cell:/c%3A/Users/nicho/Documents/research/ga-tax-assessment/paulding/eda.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     features=[TextractFeatures.FORMS, TextractFeatures.TABLES],
# ...

# %%
extractor

# %%
reader = PdfReader('../data/paulding/parcels/2011 DIGEST VENDOR FILES/Record_Layout_Paulding_Georgia.pdf')
page = reader.pages[0]
text = page.extract_text()
text
# Out:
# ' \n1 1\nBanker & Tradesman Extended Extract File Layout    (Text Output) 1172 ch \n             \nDescription    \n   \nAccount Number 1-10 10 \nParcel ID Number 11-30 20 \nUser Account Number 31-40 10 \nLocation Street Number 41-50 10 \nLocation Alternate Street Number  51-60 10 \nLocation Street Name  61-85 25 \nCondo Unit Number  86-95 10 \nCondo Complex Name 96-105 10 \nOwner Name #1 106-135 30 \nOwner Name #2 136-165 30 \nOwner Name #3 166-195 30 \nMailing Address Line 1 196-225 30 \nMailing Address Line 2  226-255 30 \nMailing City  256-280 25 \nMailing State 281-290 10 \nMailing Zip Code 291-300 10 \nOwner Occupied 301-301 1 \nZoning Code 1 302-311 10 \nFlood Hazard Code 312-321 10 \nCensus Code 322-331 10 \nUtility Code 1  332-341 10 \nUtility Code 2  342-351 10 \nUtility Code 3 352-361 10 \nTraffic Code 362-371 10 \nPrimary Land Use Code (LUC) (4th  372-375 4 \nYear Built 376-379 4 \nEffective Year Built 380-383 4 \nTotal Acres 384-393 10 \nGross Building Area  394-403 10 \
# ...

# %%
[texttext.split('\n')
# Out:
# [' ',
#  '1 1',
#  'Banker & Tradesman Extended Extract File Layout    (Text Output) 1172 ch ',
#  '             ',
#  'Description    ',
#  '   ',
#  'Account Number 1-10 10 ',
#  'Parcel ID Number 11-30 20 ',
#  'User Account Number 31-40 10 ',
#  'Location Street Number 41-50 10 ',
#  'Location Alternate Street Number  51-60 10 ',
#  'Location Street Name  61-85 25 ',
#  'Condo Unit Number  86-95 10 ',
#  'Condo Complex Name 96-105 10 ',
#  'Owner Name #1 106-135 30 ',
#  'Owner Name #2 136-165 30 ',
#  'Owner Name #3 166-195 30 ',
#  'Mailing Address Line 1 196-225 30 ',
#  'Mailing Address Line 2  226-255 30 ',
#  'Mailing City  256-280 25 ',
#  'Mailing State 281-290 10 ',
#  'Mailing Zip Code 291-300 10 ',
#  'Owner Occupied 301-301 1 ',
#  'Zoning Code 1 302-311 10 ',
#  'Flood Hazard Code 312-321 10 ',
#  'Census Code 322-331 10 ',
#  'Utility Code 1  332-341 10 ',
#  'Utility Code 2  342-351 10 ',
#  'Utility Code 3 352-361 10 ',
#  'Traffic Code 362-371 10 ',
# ...

# %%
dp2011 = pd.read_csv('../data/paulding/parcels/2011 DIGEST VENDOR FILES/PAULDING_GA_2011_REAL_DIGEST.txt',
                    delim_whitespace=True, on_bad_lines='skip')
# Out:
# C:\Users\nicho\AppData\Local\Temp\ipykernel_3784\1738806829.py:1: DtypeWarning: Columns (94) have mixed types. Specify dtype option on import or set low_memory=False.
#   dp2011 = pd.read_csv('../data/paulding/parcels/2011 DIGEST VENDOR FILES/PAULDING_GA_2011_REAL_DIGEST.txt',

# %%
dp2011
# Out:
#            1  049.2.4.016.0000        6821 CARTERSVILLE     HWY          THE  \
# 0          2  146.4.3.054.0000         445        WATTS      RD      THAXTON
# 1          3  110.4.4.041.0000         157         MILL      CT     JACKLINE
# 2          4  083.3.2.009.0000         276        MARTY      LN  SOUTHERLAND
# 3          5  112.3.2.054.0000         944        HARDY     CIR     ROBINSON
# 4          6  253.3.2.019.0000         402   FRIENDSHIP  CHURCH           RD
# ...      ...               ...         ...          ...     ...          ...
# 64426  82028  009.3.1.010.0000  UNASSIGNED     BEECHNER    PAUL          CHO
# 64427  82029  118.1.1.008.001B         661    MCPHERSON    LOOP        HOGAN
# 64428  82030  103.4.2.008.002B         199    NORTHSIDE  CHURCH           RD
# 64429  82031  235.2.4.005.001B        3970     MULBERRY    ROCK           RD
# 64430  82032  132.3.3.001.001B         530      AIRPORT    PKWY       MCNEEL
#
# ...

# %%
d2011 = pl.read_csv('../data/paulding/parcels/2011 DIGEST VENDOR FILES/PAULDING_GA_2011_REAL_DIGEST.txt',
                    separator=" ", infer_schema_length=0)

# %%
d2011
# Out:
# shape: (65_005, 757)
# ┌───────┬──────┬─────────────┬─────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 1     ┆      ┆ _duplicated ┆ _duplicated ┆ … ┆ _duplicate ┆ _duplicate ┆ _duplicate ┆ _duplicate │
# │ ---   ┆ ---  ┆ _0          ┆ _1          ┆   ┆ d_657      ┆ d_658      ┆ d_659      ┆ d_660      │
# │ str   ┆ str  ┆ ---         ┆ ---         ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │       ┆      ┆ str         ┆ str         ┆   ┆ str        ┆ str        ┆ str        ┆ str        │
# ╞═══════╪══════╪═════════════╪═════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2     ┆ null ┆ null        ┆ null        ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 3     ┆ null ┆ null        ┆ null        ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 4     ┆ null ┆ null        ┆ null        ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# ...
